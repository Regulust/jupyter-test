# %% [markdown]
# # Jupyter Learning & test

# %% [markdown]
# ## Hello World

# %%
print ("Hello world! This is Jupyter test.")
# Out:
# Hello world! This is Jupyter.

# %% [markdown]
# ## Jupyter + matplotlib 绘图

# %%
# %matplotlib inline 
# 直接嵌入图表，可以不用plt.show()
# %matplotlib widget
# this sets up the Matplotlib interactive windows:

# %% [markdown]
# ### Figure

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
fig.suptitle('No axes on this fig')
fig, ax_lst = plt.subplots(2,2)

# %%
# ref: https://www.cnblogs.com/lduml/p/13577580.html
# ref: https://blog.csdn.net/smartboy_01/article/details/113062855

# %%
import matplotlib.pyplot as plt

x_data = ['2011','2012','2013','2014','2015','2016','2017']
y_data = [58000,60200,63000,71000,84000,90500,107000]

# plt.figure(figsize=(5, 5), dpi=100)

plt.plot(x_data,y_data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x_data = ['2011','2012','2013','2014','2015','2016','2017']
y_data = [58000,60200,63000,71000,84000,90500,107000]
y_data2 = [52000,54200,51500,58300,56800,59500,62700]
y_data3 = np.array(y_data)*0.6 + np.array(y_data2)*0.8

plt.plot(x_data,y_data,color='red',linewidth=2.0,linestyle='--')
plt.plot(x_data,y_data2,color='blue',linewidth=3.0,linestyle='-.')
plt.plot(x_data,y_data3,color='orange',linewidth=2.0,linestyle='-')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm  #字体管理器
plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题

x_data = ['2011','2012','2013','2014','2015','2016','2017']
y_data = [58000,60200,63000,71000,84000,90500,107000]
y_data2 = [52000,54200,51500,58300,56800,59500,62700]

ln1, = plt.plot(x_data,y_data,color='red',linewidth=2.0,linestyle='--')
ln2, = plt.plot(x_data,y_data2,color='blue',linewidth=3.0,linestyle='-.')

plt.title("电子产品销售量Electronic product sales") #设置标题及字体 电子产品销售量

plt.legend(handles=[ln1,ln2],labels=['Annual Mouse sales','Annual keyboard sales']) # '鼠标的年销量','键盘的年销量'

ax = plt.gca()
ax.spines['right'].set_color('none')  # right边框属性设置为none 不显示
ax.spines['top'].set_color('none')    # top边框属性设置为none 不显示

plt.show()

# %% [markdown]
# ## Python 数组对应相加

# %%
# Python 数组对应相加
# ref: https://www.cnblogs.com/darlingmz/p/13748695.html
import numpy as np
y_data = [58000,60200,63000,71000,84000,90500,107000]
y_data2 = [52000,54200,51500,58300,56800,59500,62700]
y_data3 = y_data + y_data2
y_data4 = np.array(y_data) + np.array(y_data2)
y_data5 = np.array(y_data) * 0.2
print(y_data)
print(y_data2)
print(y_data3)
print(y_data4)
print(y_data5)
# Out:
# [58000, 60200, 63000, 71000, 84000, 90500, 107000]
# [52000, 54200, 51500, 58300, 56800, 59500, 62700]
# [58000, 60200, 63000, 71000, 84000, 90500, 107000, 52000, 54200, 51500, 58300, 56800, 59500, 62700]
# [110000 114400 114500 129300 140800 150000 169700]
# [11600. 12040. 12600. 14200. 16800. 18100. 21400.]
